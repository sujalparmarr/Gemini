# %%
import os
os.environ["GOOGLE_API_KEY"] = ""

# %%
from google import genai
client=genai.Client()

# %%
from google import genai
from google.genai  import types
client = genai.Client()

response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents="Explain photosynthesis with an analogy",
  config= types.GenerateContentConfig(
      thinking_config= types.ThinkingConfig(
          include_thoughts=True
      )
  )
)

response
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=10>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         inline_data=Blob(
#           data=b'\xc1\xff\xc1\xff?\x00\x7f\x00?\x00\x00\x00\x00\x00?\x00\x7f\x00\x7f\x00\xbf\x00?\x00\x00\x00\xc1\xff\x81\xff\xe1\xff\x00\x00\x00\x00\x00\x00\xe1\xff\x81\xff\xa1\xff\xe1\xff?\x00\x7f\x00\x7f\x00?\x00\xe1\xff\xc1\xff\xe1\xff\xa1\xff\x81\xff\xc1\xff?\x00\x7f\x00?\x00\x00\x00\xc1\xff\x81\xff\x00\x00\x7f\x00\x7f\x00?\x00\xa1\xffa\xff!\xffa\xff\xe1\xff?...',
#           mime_type='audio/L16;codec=pcm;rate=24000'
#         )
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-2.5-flash-preview-tts' prompt_feedback=None response_id='du8Iadv6G6CH-8YP6JyeqQE' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=143,
#   candidates_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.AUDIO: 'AUDIO'>,
#       token_count=143
#     ),
#   ],
#   prompt_token_count=12,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=12
#     ),
#   ],
#   total_token_count=155
# ) automatic_function_calling_history=[] parsed=None

# %%
from google import genai
from google.genai import types

prompt = (
    "Four employees — A, B, C, and D — were in the office when a system error occurred. "
    "A says: 'B did it.' B says: 'D did it.' C says: 'I didn’t do it.' D says: 'B is lying.' "
    "Only one person is telling the truth. Who caused the error?")


client = genai.Client()
response = client.models.generate_content(
  model="gemini-2.5-pro",
  contents=prompt,
  config=types.GenerateContentConfig(
    thinking_config=types.ThinkingConfig(
      include_thoughts=True
    )
  )
)

print(response.text)
# Out:
# Let's break down the logic to find the culprit. We know only one person is telling the truth.
#
# We can test each person as the culprit to see which scenario results in only one true statement.
#
# **Statements:**
# *   **A:** 'B did it.'
# *   **B:** 'D did it.'
# *   **C:** 'I didn’t do it.'
# *   **D:** 'B is lying.'
#
# **Let's analyze each possibility:**
#
# *   **Scenario 1: A did it.**
#     *   A's statement ('B did it') is **false**.
#     *   B's statement ('D did it') is **false**.
#     *   C's statement ('I didn’t do it') is **true**.
#     *   D's statement ('B is lying') is **true** (because B's statement is false).
#     *   *Result: Two people (C and D) are telling the truth. This contradicts the rule.*
#
# *   **Scenario 2: B did it.**
#     *   A's statement ('B did it') is **true**.
#     *   B's statement ('D did it') is **false**.
#     *   C's statement ('I didn’t do it') is **true**.
#     *   D's statement ('B is lying') is **true**.
#     *   *Result: Three people (A, C, and D) are telling the truth. This contradicts the rule.*
#
# *   **Scenario 3: C did it.**
#     *   A's statement ('B did it') is **false**.
#     *   B's statement ('D did it') is **false**.
#     *   C's statement ('I didn’t do it') is **false**.
#     *   D's statement ('B is lying') is **true** (because B's statement is false).
#     *   *Result: Exactly one person (D) is telling the truth. This fits the rule perfectly.*
#
# *   **Scenario 4: D did it.**
#     *   A's statement ('B did it') is **false**.
#     *   B's statement ('D did it') is **true**.
#     *   C's statement ('I didn’t do it') is **true**.
#     *   D's statement ('B is lying') is **false** (because B is telling the truth).
#     *   *Result: Two people (B and C) are telling the truth. This contradicts the rule.*
#
# The only scenario that works is Scenario 3.
#
# Therefore, **C caused the error.**
