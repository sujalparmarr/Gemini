# %%
# !pip install -q google-generativeai

# %%
import os
os.environ["GOOGLE_API_KEY"] = ""

# %%
from google import genai
from google.genai import types
client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents= types.Content(
        parts=[
            types.Part(
            file_data= types.FileData(file_uri ="https://www.youtube.com/watch?v=M-ZH3psUbfU" )
        ),
            types.Part(text="Summarize this video.")
            ]
    )
)

# %%
print(response.text)
# Out:
# The video features Lex Fridman interviewing Elon Musk. The main topic of their conversation is career and life advice for young people. Elon Musk suggests that young people should try to be useful to humanity, focusing on contributing more than they consume. He emphasizes the importance of gaining broad knowledge by reading many books and having a good general understanding of different subjects. Additionally, he advises finding an overlap between one's talents and interests. Towards the end of the video, Musk stresses the importance of having a "grow the pie" mindset rather than a "zero-sum" mentality, where success is not at the expense of others.
